# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv(r'PAH_April_2022.csv', encoding='latin1')

# %%
df['Date'] = pd.to_datetime(df['Visit Date']).dt.day

# %%
df['day'] = pd.to_datetime(df['Visit Date']).dt.dayofweek

# %%
df['day'].value_counts()
# Out:
# 5    2736
# 0    2389
# 4    2368
# 1    1996
# 2    1840
# 3    1710
# 6    1118
# Name: day, dtype: int64

# %%
df.head(100)
# Out:
#     Visit Date Visit Date_01       HIN No.                Patient Name  \
# 0   2022-04-01    01-04-2022  1.648802e+10               VIBHA NAYYAR
# 1   2022-04-01    01-04-2022  1.648802e+10               VIBHA NAYYAR
# 2   2022-04-01    01-04-2022  1.601974e+10             MADHU BHANDARI
# 3   2022-04-01    01-04-2022  1.639805e+10                SUMAN VERMA
# 4   2022-04-01    01-04-2022  1.639805e+10                      ANITA
# ..         ...           ...           ...                         ...
# 95  2022-04-01    01-04-2022  1.648790e+10           DAYALSINGH RAWAT
# 96  2022-04-01    01-04-2022  1.648798e+10               MADHUR VERMA
# 97  2022-04-01    01-04-2022  1.648811e+10  SHRI GOPAL DHAR BADGAIYAN
# 98  2022-04-01    01-04-2022  1.645675e+10              POONAM BANSAL
# 99  2022-04-01    01-04-2022  1.647082e+10                 MANJU RANI
#
#     Patient_Phone1  Age Age Group  Gender                    Category  \
# ...
